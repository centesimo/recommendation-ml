# %% [markdown]
# ## 1. Instalação
#
#
# Antes de rodar esse notebook, crie um serviço de machile learning do Watson
#
# * Create a Watson Machine Learning service instance (a free plan is offered) and associate it with your project

# %% [markdown]
# We'll be using a few libraries for this exercise:
#
# 1. [Watson Machine Learning Client](http://wml-api-pyclient.mybluemix.net/): Client library to work with the Watson Machine Learning service on IBM Cloud. Library available on [pypi](https://pypi.org/project/watson-machine-learning-client/). Service available on [IBM Cloud](https://cloud.ibm.com/catalog/services/machine-learning).
# 1. [Pixiedust](https://github.com/pixiedust/pixiedust): Python Helper library for Jupyter Notebooks. Available on [pypi](https://pypi.org/project/pixiedust/).
# 1. [ibmos2spark](https://github.com/ibm-watson-data-lab/ibmos2spark): Facilitates Data I/O between Spark and IBM Object Storage services

# %%
# !pip install --upgrade ibmos2spark
# !pip install --upgrade pixiedust
#!pip install watson-machine-learning-client-V4
# !pip install -U ibm-watson-machine-learning
# Out:
# Waiting for a Spark session to start...
# Spark Initialization Done! ApplicationId = app-20210507182551-0000
# KERNEL_ID = c17fa639-1f91-4160-87e4-19e27e162346
# Collecting ibmos2spark
#   Downloading ibmos2spark-1.0.1-py2.py3-none-any.whl (7.4 kB)
# Installing collected packages: ibmos2spark
# Successfully installed ibmos2spark-1.0.1
# Collecting pixiedust
#   Downloading pixiedust-1.1.19.tar.gz (197 kB)
#      |████████████████████████████████| 197 kB 15.9 MB/s eta 0:00:01
# Collecting geojson
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting astunparse
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting markdown
#   Downloading Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 4.6 MB/s  eta 0:00:01
# Collecting colour
#   Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Collecting requests
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 7.4 MB/s  eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.4.1-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 19.0 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 61.1 MB/s eta 0:00:01
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting six<2.0,>=1.6.1
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 3.4 MB/s  eta 0:00:01
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 43.2 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 91.8 MB/s eta 0:00:01
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 97.8 MB/s eta 0:00:01
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 5.4 MB/s  eta 0:00:01
# Collecting numpy>=1.16
#   Downloading numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 26.6 MB/s eta 0:00:01
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
#      |████████████████████████████████| 227 kB 90.8 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 19.6 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 73.1 MB/s eta 0:00:01
# Collecting pytz>=2017.3
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 58.8 MB/s eta 0:00:01
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Building wheels for collected packages: pixiedust
#   Building wheel for pixiedust (setup.py) ... done
#   Created wheel for pixiedust: filename=pixiedust-1.1.19-py3-none-any.whl size=321803 sha256=f784285e9a24d479cd69ae2fdb403c2869a0182b1861c08c7453896a28abbaf8
#   Stored in directory: /home/spark/shared/.cache/pip/wheels/05/07/e7/8aca0e820027a63157a916424fd748fb2a2a3e71de5e08eeb8
# Successfully built pixiedust
# ERROR: conda 4.8.2 requires ruamel_yaml>=0.11.14, which is not installed.
# ERROR: tensorflow 2.1.0 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.5.0 which is incompatible.
# ERROR: ibm-watson-machine-learning 1.0.38 has requirement pandas<=1.0.5, but you'll have pandas 1.2.4 which is incompatible.
# ERROR: botocore 1.16.11 has requirement urllib3<1.26,>=1.20, but you'll have urllib3 1.26.4 which is incompatible.
# ERROR: aiohttp 3.6.2 has requirement chardet<4.0,>=2.0, but you'll have chardet 4.0.0 which is incompatible.
# Installing collected packages: geojson, wheel, six, astunparse, typing-extensions, zipp, importlib-metadata, markdown, colour, idna, chardet, certifi, urllib3, requests, pyparsing, numpy, python-dateutil, cycler, pillow, kiwisolver, matplotlib, pytz, pandas, pixiedust
# Successfully installed astunparse-1.6.3 certifi-2020.12.5 chardet-4.0.0 colour-0.1.5 cycler-0.10.0 geojson-2.5.0 idna-2.10 importlib-metadata-4.0.1 kiwisolver-1.3.1 markdown-3.3.4 matplotlib-3.4.1 numpy-1.20.2 pandas-1.2.4 pillow-8.2.0 pixiedust-1.1.19 pyparsing-2.4.7 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 six-1.16.0 typing-extensions-3.10.0.0 urllib3-1.26.4 wheel-0.36.2 zipp-3.4.1
# Collecting ibm-watson-machine-learning
#   Downloading ibm_watson_machine_learning-1.0.79-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 11.1 MB/s eta 0:00:01
# Collecting certifi
#   Using cached certifi-2020.12.5-py2.py3-none-any.whl (147 kB)
# Collecting packaging
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 2.9 MB/s  eta 0:00:01
# Collecting ibm-cos-sdk==2.7.*
#   Downloading ibm-cos-sdk-2.7.0.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 416 kB/s  eta 0:00:01
# Collecting lomond
#   Downloading lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Collecting requests
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting urllib3
#   Using cached urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting pandas<1.3.0,>=0.24.2
#   Using cached pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
# Collecting tabulate
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting pyparsing>=2.0.2
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting ibm-cos-sdk-core==2.7.0
#   Downloading ibm-cos-sdk-core-2.7.0.tar.gz (824 kB)
#      |████████████████████████████████| 824 kB 81.0 MB/s eta 0:00:01
# Collecting ibm-cos-sdk-s3transfer==2.7.0
#   Downloading ibm-cos-sdk-s3transfer-2.7.0.tar.gz (133 kB)
#      |████████████████████████████████| 133 kB 43.7 MB/s eta 0:00:01
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting six>=1.10.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting chardet<5,>=3.0.2
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting pytz>=2017.3
#   Using cached pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting numpy>=1.16.5
#   Using cached numpy-1.20.2-cp37-cp37m-manylinux2010_x86_64.whl (15.3 MB)
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
#      |████████████████████████████████| 547 kB 74.3 MB/s eta 0:00:01
# Building wheels for collected packages: ibm-cos-sdk, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer
#   Building wheel for ibm-cos-sdk (setup.py) ... done
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.7.0-py2.py3-none-any.whl size=72555 sha256=cb844defed680b61f05bfe1568cfcda5801cf3b14e787e96b1715cc64e49ef48
#   Stored in directory: /home/spark/shared/.cache/pip/wheels/47/22/bf/e1154ff0f5de93cc477acd0ca69abfbb8b799c5b28a66b44c2
#   Building wheel for ibm-cos-sdk-core (setup.py) ... done
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.7.0-py2.py3-none-any.whl size=500999 sha256=9e3688b3150d67c36a944c759eecad166a753f8060967a049b046c466d45f06b
#   Stored in directory: /home/spark/shared/.cache/pip/wheels/6c/a2/e4/c16d02f809a3ea998e17cfd02c13369281f3d232aaf5902c19
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py) ... done
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.7.0-py2.py3-none-any.whl size=88603 sha256=6098b3f9831fa15ea622d4fdddde128d86fe1ba9fb52957698284ee0f8c49295
#   Stored in directory: /home/spark/shared/.cache/pip/wheels/5f/b7/14/fbe02bc1ef1af890650c7e51743d1c83890852e598d164b9da
# Successfully built ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# ERROR: conda 4.8.2 requires ruamel_yaml>=0.11.14, which is not installed.
# ERROR: tensorflow 2.1.0 has requirement scipy==1.4.1; python_version >= "3", but you'll have scipy 1.5.0 which is incompatible.
# ERROR: botocore 1.16.11 has requirement urllib3<1.26,>=1.20, but you'll have urllib3 1.26.4 which is incompatible.
# ERROR: aiohttp 3.6.2 has requirement chardet<4.0,>=2.0, but you'll have chardet 4.0.0 which is incompatible.
# Installing collected packages: certifi, pyparsing, packaging, jmespath, docutils, chardet, idna, urllib3, requests, six, python-dateutil, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, lomond, pytz, numpy, pandas, tabulate, ibm-watson-machine-learning
# Successfully installed certifi-2020.12.5 chardet-4.0.0 docutils-0.15.2 ibm-cos-sdk-2.7.0 ibm-cos-sdk-core-2.7.0 ibm-cos-sdk-s3transfer-2.7.0 ibm-watson-machine-learning-1.0.79 idna-2.10 jmespath-0.10.0 lomond-0.3.3 numpy-1.20.2 packaging-20.9 pandas-1.2.4 pyparsing-2.4.7 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 six-1.16.0 tabulate-0.8.9 urllib3-1.26.4

# %%
import pixiedust
# Out:
# Pixiedust database opened successfully
# Table VERSION_TRACKER created successfully
# Table METRICS_TRACKER created successfully
#
# Share anonymous install statistics? (opt-out instructions)
#
# PixieDust will record metadata on its environment the next time the package is installed or updated. The data is anonymized and aggregated to help plan for future releases, and records only the following values:
#
# {
#    "data_sent": currentDate,
#    "runtime": "python",
#    "application_version": currentPixiedustVersion,
#    "space_id": nonIdentifyingUniqueId,
#    "config": {
#        "repository_id": "https://github.com/ibm-watson-data-lab/pixiedust",
#        "target_runtimes": ["Data Science Experience"],
#        "event_id": "web",
#        "event_organizer": "dev-journeys"
#    }
# }
# You can opt out by calling pixiedust.optOut() in a new cell.
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.19</span>
#         </div>
# Pixiedust runtime updated. Please restart kernel
# Table SPARK_PACKAGES created successfully
# Table USER_PREFERENCES created successfully
# Table service_connections created successfully

# %%
#access_base = pixiedust.sampleData('https://raw.githubusercontent.com/centesimo/recommendation-ml/master/data/base_help_outubro.csv')
access_base = pixiedust.sampleData('https://raw.githubusercontent.com/centesimo/recommendation-ml/master/data/watson_cr_07052021.csv')
# Out:
# Downloading 'https://raw.githubusercontent.com/centesimo/recommendation-ml/master/data/watson_cr_07052021.csv' from https://raw.githubusercontent.com/centesimo/recommendation-ml/master/data/watson_cr_07052021.csv
# Downloaded 1962452 bytes
# Creating pySpark DataFrame for 'https://raw.githubusercontent.com/centesimo/recommendation-ml/master/data/watson_cr_07052021.csv'. Please wait...
# Loading file using 'SparkSession'
# Successfully created pySpark DataFrame for 'https://raw.githubusercontent.com/centesimo/recommendation-ml/master/data/watson_cr_07052021.csv'

# %% [markdown]
# <a id="kmeans"></a>
# ## 3. Create a *k*-means model with Spark
#
# In this section of the notebook you use the *k*-means implementation to associate every customer to a cluster based on their shopping history.
#
# First, import the Apache Spark Machine Learning packages ([MLlib](http://spark.apache.org/docs/2.2.0/api/python/pyspark.ml.html)) that you need in the subsequent steps:

# %%
from pyspark.ml import Pipeline
from pyspark.ml.clustering import KMeans
from pyspark.ml.clustering import KMeansModel
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.linalg import Vectors

procedures_cols = access_base.drop('produto_id', '_c820').columns

# %%
product_id = access_base.drop('procedure_id', '_c820').columns
print(product_id)
# Out:
# ['produto_id', '32', '40', '47', '51', '52', '53', '55', '57', '60', '61', '69', '71', '91', '118', '122', '126', '136', '140', '141', '144', '145', '146', '149', '151', '152', '153', '155', '156', '159', '163', '165', '167', '178', '182', '183', '184', '185', '186', '188', '194', '231', '232', '234', '239', '240', '244', '249', '250', '262', '270', '282', '283', '285', '290', '292', '300', '301', '302', '308', '310', '322', '325', '328', '329', '333', '334', '335', '338', '339', '340', '347', '348', '354', '355', '357', '362', '370', '373', '379', '381', '382', '388', '389', '396', '397', '398', '403', '404', '419', '421', '423', '425', '427', '430', '431', '437', '447', '451', '453', '466', '469', '479', '480', '483', '484', '486', '487', '490', '491', '492', '494', '507', '510', '512', '517', '520', '525', '527', '532', '533', '537', '541', '542', '543', '544', '545', '547', '549', '550', '554', '556', '557', '561', '564', '565', '569', '570', '574', '582', '591', '594', '596', '598', '599', '606', '613', '614', '617', '619', '620', '624', '627', '633', '636', '637', '640', '647', '648', '666', '672', '681', '682', '685', '687', '688', '691', '694', '697', '711', '721', '746', '765', '772', '774', '775', '776', '796', '805', '817', '820', '823', '831', '839', '840', '842', '843', '845', '846', '848', '859', '860', '862', '863', '864', '865', '867', '869', '870', '892', '895', '904', '908', '914', '952', '954', '1000', '1001', '1030', '1031', '1069', '1113', '1128', '1133', '1141', '1145', '1146', '1147', '1159', '1169', '1174', '1178', '1185', '1187', '1188', '1195', '1212', '1229', '1233', '1237', '1249', '1298', '1299', '1302', '1308', '1311', '1314', '1315', '1319', '1323', '1326', '1330', '1332', '1338', '1342', '1344', '1345', '1349', '1355', '1361', '1365', '1366', '1367', '1368', '1369', '1370', '1376', '1377', '1379', '1380', '1384', '1393', '1401', '1405', '1409', '1413', '1425', '1430', '1432', '1442', '1447', '1450', '1452', '1455', '1457', '1461', '1463', '1464', '1469', '1470', '1472', '1474', '1476', '1477', '1483', '1488', '1490', '1507', '1514', '1544', '1554', '1560', '1566', '1568', '1574', '1617', '1664', '1733', '1755', '1759', '1763', '1768', '1776', '1791', '1793', '1796', '1824', '1864', '1866', '1872', '1891', '1907', '1974', '1978', '1979', '1982', '2008', '2009', '2017', '2033', '2034', '2051', '2053', '2054', '2057', '2059', '2060', '2064', '2071', '2078', '2084', '2095', '2096', '2098', '2524', '2539', '2544', '2549', '2554', '2556', '2564', '2576', '2596', '2612', '2616', '2660', '2680', '2708', '2716', '2720', '2731', '2732', '2733', '2734', '2749', '2751', '2759', '2760', '2761', '2765', '2770', '2780', '2783', '2784', '2785', '2787', '2793', '2794', '2795', '2803', '2808', '2812', '2820', '2822', '2824', '2825', '2826', '2830', '2833', '2835', '2836', '2837', '2838', '2839', '2840', '2841', '2845', '2846', '2847', '2848', '2849', '2851', '2872', '2875', '2879', '2883', '2884', '2886', '2887', '2891', '2892', '2893', '2897', '2898', '2899', '2922', '2935', '2951', '2961', '2964', '3007', '3012', '3013', '3019', '3021', '3022', '3064', '3066', '3078', '3087', '3101', '3111', '3128', '3143', '3144', '3147', '3150', '3151', '3152', '3162', '3163', '3164', '3169', '3192', '3193', '3196', '3200', '3204', '3228', '3230', '3231', '3232', '3246', '3248', '3250', '3254', '3275', '3284', '3285', '3286', '3292', '3293', '3302', '3328', '3350', '3352', '3353', '3355', '3363', '3369', '3371', '3372', '3373', '3376', '3377', '3382', '3384', '3387', '3389', '3408', '3410', '3414', '3418', '3423', '3425', '3429', '3435', '3437', '3441', '3443', '3459', '3460', '3462', '3470', '3472', '3478', '3479', '3481', '3484', '3487', '3495', '3499', '3502', '3510', '3515', '3521', '3523', '3535', '3536', '3541', '3552', '3557', '3559', '3561', '3563', '3564', '3565', '3567', '3568', '3574', '3579', '3580', '3584', '3586', '3589', '3611', '3613', '3615', '3616', '3618', '3625', '3636', '3648', '3657', '3658', '3667', '36 ...

# %% [markdown]
# <a id="prepare_data"></a>
# ### 3.1 Prepare data
#
# Create a new data set with just the data that you need. Filter the columns that you want, in this case the customer ID column and the product-related columns. Remove the columns that you don't need for aggregating the data and training the model:
#
# ### We won't need this part because out data allready have formated
# # Just go to the part 3.2 below

# %% [markdown]
# <a id="build_model"></a>
# ### 3.2 Create clusters and define the model
#
# Create 100 clusters with a *k*-means model based on the number of times a specific customer purchased a product.
#
# First, create a feature vector by combining the product and quantity columns:

# %%
assembler = VectorAssembler(inputCols=["{}".format(x) for x in procedures_cols],outputCol="features") # Assemble vectors using product fields

# %% [markdown]
# Next, create the *k*-means clusters and the pipeline to define the model:

# %%
kmeans = KMeans(maxIter=10, predictionCol="cluster").setK(100).setSeed(1)  # Initialize model
pipeline = Pipeline(stages=[assembler, kmeans])
model = pipeline.fit(access_base)

# %%
help_cluster = model.transform(access_base)

# %% [markdown]
# # Here we compare many clusters to get the better cluster for our application

# %% [markdown]
# <a id="persist"></a>
# ## 4. Persist the model
#
# In this section you will learn how to store your pipeline and model in Watson Machine Learning repository by using Python client libraries.

# %% [markdown]
# <a id="persist"></a>
# ## Now to access the machine Learning of Watson we must use IAM KEY and get a token to access the same.
#
# Below are the code to get the token

# %%
import requests

apikey = "75LWtvCg0l7p75_1dsWoXWVHA3jvXpZunfV1GQULnKzC"

# Get an IAM token from IBM Cloud
url     = "https://iam.bluemix.net/oidc/token"
headers = { "Content-Type" : "application/x-www-form-urlencoded" }
data    = "apikey=" + apikey + "&grant_type=urn:ibm:params:oauth:grant-type:apikey"
IBM_cloud_IAM_uid = "bx"
IBM_cloud_IAM_pwd = "bx"
response  = requests.post( url, headers=headers, data=data, auth=( IBM_cloud_IAM_uid, IBM_cloud_IAM_pwd ) )
iam_token = response.json()["access_token"]

print('Token = '+iam_token)
# Out:
# Token = eyJraWQiOiIyMDIxMDQyMDE4MzYiLCJhbGciOiJSUzI1NiJ9.....p_cNJmSlMa-rv7SrwDQ_bah8F2VTXQV78iJfeBJRdPpHEHRWP9Xm1naro8cy9deb5cQLFnYbbR226kiP6ICcY1MDvknnU0W7-9nnL0bO7uE9VgwZ-Q3QG6tex0YJkPPXDo4Q7WuLGbhv0vPa_GroKLBcXKbdGXQei44IF8zhOR-Q4Q3W2mhP0UpsRWKHFDpvBURdmYaw25tNMCkyYoDD0qq-9KeYugOoV7rgUvVDpR4zEuvfh0TqxTfOjLTpN_QqNHMTFJukQcQBks_5-FofIr0Qocof8q4V6y4sLgKpu5fw26Wq-wdK7oHdRIcDacWNlGURYt5zKVrCV7FxqrQqEA

# %%
wml_credentials = {
                   "url": "https://us-south.ml.cloud.ibm.com",
                   "apikey":"l9QiumN1_TS0xNhRDhdKeuqVkmshTHhim0d300wKI-Y9",
                  }

from ibm_watson_machine_learning import APIClient
client = APIClient(wml_credentials)
client.set.default_space("0c9fcc9d-6471-478f-80d3-c5b2382dea8f")
# Out:
# 'SUCCESS'

# %% [markdown]
# ### 4.1 Configure IBM Watson Machine Learning credentials
#
# To access your machine learning repository programmatically, you need to copy in your credentials, which you can see in your **IBM Watson Machine Learning** service details in IBM Cloud.
#
# > **IMPORTANT**: Update `apikey` and `instance_id` below. Credentials can be found on _Service Credentials_ tab of the Watson Machine Learning service instance created on the IBM Cloud.

# %% [markdown]
# Connect to the Watson Machine Learning service using the provided credentials.

# %% [markdown]
# ### 4.2 Save the model
#
# #### Save the model to the Watson Machine Learning repository
#
# You use the Watson Machine Learning client's [Repository class](http://wml-api-pyclient.mybluemix.net/#repository) to store and manage models in the Watson Machine Learning service.
#
# > **NOTE**: You can also use Watson Studio to manage models. In this notebook we are using the client library instead.

# %%
train_data = access_base.withColumnRenamed('produto_id', 'label')
#client.repository.ModelMetaNames.show()
#client.service_instance.get_details()

# %%
train_data
# Out:
# DataFrame[label: int, 32: double, 40: double, 47: double, 51: double, 52: double, 53: double, 55: double, 57: double, 60: double, 61: double, 69: double, 71: double, 91: double, 118: double, 122: double, 126: double, 136: double, 140: double, 141: double, 144: double, 145: double, 146: double, 149: double, 151: double, 152: double, 153: double, 155: double, 156: double, 159: double, 163: double, 165: double, 167: double, 178: double, 182: double, 183: double, 184: double, 185: double, 186: double, 188: double, 194: double, 231: double, 232: double, 234: double, 239: double, 240: double, 244: double, 249: double, 250: double, 262: double, 270: double, 282: double, 283: double, 285: double, 290: double, 292: double, 300: double, 301: double, 302: double, 308: double, 310: double, 322: double, 325: double, 328: double, 329: double, 333: double, 334: double, 335: double, 338: double, 339: double, 340: double, 347: double, 348: double, 354: double, 355: double, 357: double, 362: double, 370: double, 373: double, 379: double, 381: double, 382: double, 388: double, 389: double, 396: double, 397: double, 398: double, 403: double, 404: double, 419: double, 421: double, 423: double, 425: double, 427: double, 430: double, 431: double, 437: double, 447: double, 451: double, 453: double, 466: double, 469: double, 479: double, 480: double, 483: double, 484: double, 486: double, 487: double, 490: double, 491: double, 492: double, 494: double, 507: double, 510: double, 512: double, 517: double, 520: double, 525: double, 527: double, 532: double, 533: double, 537: double, 541: double, 542: double, 543: double, 544: double, 545: double, 547: double, 549: double, 550: double, 554: double, 556: double, 557: double, 561: double, 564: double, 565: double, 569: double, 570: double, 574: double, 582: double, 591: double, 594: double, 596: double, 598: double, 599: double, 606: double, 613: double, 614: double, 617: double, 619: double, 620: double, 624: double, 627: double, 633: double, 636: double, 637: double, 640: double, 647: double, 648: double, 666: double, 672: double, 681: double, 682: double, 685: double, 687: double, 688: double, 691: double, 694: double, 697: double, 711: double, 721: double, 746: double, 765: double, 772: double, 774: double, 775: double, 776: double, 796: double, 805: double, 817: double, 820: double, 823: double, 831: double, 839: double, 840: double, 842: double, 843: double, 845: double, 846: double, 848: double, 859: double, 860: double, 862: double, 863: double, 864: double, 865: double, 867: double, 869: double, 870: double, 892: double, 895: double, 904: double, 908: double, 914: double, 952: double, 954: double, 1000: double, 1001: double, 1030: double, 1031: double, 1069: double, 1113: double, 1128: double, 1133: double, 1141: double, 1145: double, 1146: double, 1147: double, 1159: double, 1169: double, 1174: double, 1178: double, 1185: double, 1187: double, 1188: double, 1195: double, 1212: double, 1229: double, 1233: double, 1237: double, 1249: double, 1298: double, 1299: double, 1302: double, 1308: double, 1311: double, 1314: double, 1315: double, 1319: double, 1323: double, 1326: double, 1330: double, 1332: double, 1338: double, 1342: double, 1344: double, 1345: double, 1349: double, 1355: double, 1361: double, 1365: double, 1366: double, 1367: double, 1368: double, 1369: double, 1370: double, 1376: double, 1377: double, 1379: double, 1380: double, 1384: double, 1393: double, 1401: double, 1405: double, 1409: double, 1413: double, 1425: double, 1430: double, 1432: double, 1442: double, 1447: double, 1450: double, 1452: double, 1455: double, 1457: double, 1461: double, 1463: double, 1464: double, 1469: double, 1470: double, 1472: double, 1474: double, 1476: double, 1477: double, 1483: double, 1488: double, 1490: double, 1507: double, 1514: double, 1544: double, 1554: double, 1560: double, 1566: double, 1568: double, 1574: double, 1617: double, 1664: double, 1733: double, 1755: double, 1759: double, 1763: doub ...

# %% [markdown]
# > **TIP**: Update the cell below with your name, email, and name you wish to give to your model.

# %%
sofware_spec_uid = client.software_specifications.get_id_by_name("spark-mllib_2.4")
#client.software_specifications.list()

# %%
#client.software_specifications.get_id_by_name("spark-mllib_2.4") 
model_props = { 
        client.repository.ModelMetaNames.NAME: "Shopping Recommendation Engine", 
        client.repository.ModelMetaNames.TYPE: 'mllib_2.4', 
        client.repository.ModelMetaNames.SOFTWARE_SPEC_UID: sofware_spec_uid
}

published_model = client.repository.store_model(model=model, pipeline=pipeline, meta_props=model_props, training_data=train_data)

# %% [markdown]
# Display list of existing models in the Watson Machine Learning repository

# %%
#client.repository.list_models()

# %%
import json
saved_model_uid = client.repository.get_model_uid(published_model)
model_details = client.repository.get_details(saved_model_uid)
print(json.dumps(model_details, indent=2))
# Out:
# {
#   "entity": {
#     "label_column": "label",
#     "pipeline": {
#       "id": "7c1e9bd5-45b2-4028-bbae-46d464d4e525"
#     },
#     "software_spec": {
#       "id": "390d21f8-e58b-4fac-9c55-d7ceda621326",
#       "name": "spark-mllib_2.4"
#     },
#     "training_data_references": [
#       {
#         "connection": {
#           "access_key_id": "not_applicable",
#           "endpoint_url": "not_applicable",
#           "secret_access_key": "not_applicable"
#         },
#         "id": "1",
#         "location": {},
#         "schema": {
#           "fields": [
#             {
#               "metadata": {
#                 "modeling_role": "target"
#               },
#               "name": "label",
#               "nullable": true,
#               "type": "integer"
#             },
#             {
#               "metadata": {},
#               "name": "32",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "40",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "47",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "51",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "52",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "53",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "55",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "60",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "61",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "69",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "71",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "91",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "118",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "122",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "126",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "136",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "140",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "141",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "144",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "145",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "146",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "149",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "151",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "152",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "153",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "155",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "156",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "159",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "163",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "165",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "167",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "178",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "182",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "183",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "184",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "185",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "186",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "188",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "194",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "231",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "232",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "234",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "239",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "240",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "244",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "249",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "250",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "262",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "270",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "282",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "283",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "285",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "290",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "292",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "300",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "301",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "302",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "308",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "310",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "322",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "325",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "328",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "329",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "333",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "334",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "335",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "338",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "339",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "340",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "347",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "348",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "354",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "355",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "357",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "362",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "370",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "373",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "379",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "381",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "382",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "388",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "389",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "396",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "397",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "398",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "403",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "404",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "419",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "421",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "423",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "425",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "427",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "430",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "431",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "437",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "447",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "451",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "453",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "466",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "469",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "479",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "480",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "483",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "484",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "486",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "487",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "490",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "491",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "492",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "494",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "507",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "510",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "512",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "517",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "520",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "525",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "527",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "532",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "533",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "537",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "541",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "542",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "543",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "544",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "545",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "547",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "549",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "550",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "554",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "556",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "557",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "561",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "564",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "565",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "569",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "570",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "574",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "582",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "591",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "594",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "596",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "598",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "599",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "606",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "613",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "614",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "617",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "619",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "620",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "624",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "627",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "633",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "636",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "637",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "640",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "647",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "648",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "666",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "672",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "681",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "682",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "685",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "687",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "688",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "691",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "694",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "697",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "711",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "721",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "746",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "765",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "772",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "774",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "775",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "776",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "796",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "805",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "817",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "820",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "823",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "831",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "839",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "840",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "842",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "843",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "845",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "846",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "848",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "859",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "860",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "862",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "863",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "864",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "865",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "867",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "869",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "870",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "892",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "895",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "904",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "908",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "914",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "952",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "954",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1000",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1001",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1030",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1031",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1069",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1113",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1128",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1133",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1141",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1145",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1146",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1147",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1159",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1169",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1174",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1178",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1185",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1187",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1188",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1195",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1212",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1229",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1233",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1237",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1249",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1298",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1299",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1302",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1308",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1311",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1314",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1315",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1319",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1323",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1326",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1330",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1332",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1338",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1342",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1344",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1345",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1349",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1355",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1361",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1365",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1366",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1367",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1368",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1369",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1370",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1376",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1377",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1379",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1380",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1384",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1393",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1401",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1405",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1409",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1413",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1425",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1430",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1432",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1442",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1447",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1450",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1452",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1455",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1457",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1461",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1463",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1464",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1469",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1470",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1472",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1474",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1476",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1477",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1483",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1488",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1490",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1507",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1514",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1544",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1554",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1560",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1566",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1568",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1574",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1617",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1664",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1733",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1755",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1759",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1763",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1768",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1776",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1791",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1793",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1796",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1824",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1864",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1866",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1872",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1891",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1907",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "1974",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
# ...
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57433",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57434",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57435",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57436",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57437",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57438",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57439",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57440",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57441",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57442",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57443",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57444",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57445",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57446",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57447",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57448",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57449",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57450",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57451",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57452",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57453",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57454",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57455",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57456",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57457",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57458",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57459",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57460",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57461",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57462",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57463",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57464",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57465",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57466",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57467",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57468",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57469",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57470",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57471",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57472",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57473",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57474",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57475",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57476",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57477",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57478",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57479",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57480",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57481",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57482",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57483",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57484",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57485",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57486",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57487",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57488",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57489",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57490",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57491",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57492",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57493",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57494",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57495",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57496",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57497",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57498",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57499",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57500",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57501",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57502",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57503",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57504",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57505",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57506",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57507",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57508",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57509",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57510",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57511",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57512",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57513",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57514",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57515",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57516",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57517",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57518",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57519",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57520",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57521",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57522",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57523",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57524",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57525",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57526",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57527",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57528",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57529",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57530",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57531",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57532",
#               "nullable": true,
#               "type": "double"
#             },
#             {
#               "metadata": {},
#               "name": "57533",
#               "nullable": true,
#               "type": "double"
#             }
#           ],
#           "id": "1",
#           "type": "struct"
#         },
#         "type": "s3"
#       }
#     ],
#     "type": "mllib_2.4"
#   },
#   "metadata": {
#     "created_at": "2021-05-07T19:06:40.503Z",
#     "id": "dd032404-ff78-4d01-8133-3f3d74c6adca",
#     "modified_at": "2021-05-07T19:06:47.000Z",
#     "name": "Shopping Recommendation Engine",
#     "owner": "IBMid-550008HSDF",
#     "space_id": "0c9fcc9d-6471-478f-80d3-c5b2382dea8f"
#   },
#   "system": {
#     "warnings": []
#   }
# }

# %% [markdown]
# <a id="deploy"></a>
# ## 5. Deploy model to the IBM cloud
#
# You use the Watson Machine Learning client's [Deployments class](http://wml-api-pyclient.mybluemix.net/#deployments) to deploy and score models.
#
# ### 5.1 Create an online deployment for the model

# %%
metadata = {
    client.deployments.ConfigurationMetaNames.NAME: "Procedure Recommendation Engine Deployment",
    client.deployments.ConfigurationMetaNames.ONLINE: {}
}

created_deployment = client.deployments.create(saved_model_uid, meta_props=metadata)
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: 'dd032404-ff78-4d01-8133-3f3d74c6adca' started
#
# #######################################################################################
#
#
# initializing
# ready
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='4f8f289f-1214-4640-8ad0-1cc16a6b2bea'
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# ### 5.2 Retrieve the scoring endpoint for this model

# %%
deployments_details = client.deployments.get_details('52d20564-b164-480f-9a93-090b88b99f0e')

# %%
scoring_endpoint = client.deployments.get_scoring_href(created_deployment) 
print(scoring_endpoint)
# Out:
# https://us-south.ml.cloud.ibm.com/ml/v4/deployments/4f8f289f-1214-4640-8ad0-1cc16a6b2bea/predictions

# %% [markdown]
# <a id="test_deploy"></a>
# ### 5.3 Test the deployed model
#
# To verify that the model was successfully deployed to the cloud, you'll specify a customer ID, for example customer 14887, to predict this customer's cluster against the Watson Machine Learning deployment, and see if it matches the cluster that was previously associated this customer ID.

# %%
customer = help_cluster.collect()
print("Previously calculated cluster = {}".format(customer[0].cluster))
# Out:
# Previously calculated cluster = 1

# %% [markdown]
# To determine the customer's cluster using Watson Machine Learning, you need to load the customer's purchase history. This function uses the local data frame to select every product field and the number of times that customer 14887 purchased a product.

# %%
from six import iteritems
def get_procedure_counts_for_product(product_id):
        
    product = access_base.filter('produto_id = {}'.format(product_id)).take(1000000)       
    fields = [] 
    values = [] 
    for row in product:                
        for procedure_col in procedures_cols:
            field = procedure_col
            value = row[field]    
            fields.append(field) 
            values.append(value)    
    
    return (fields, values)

# %% [markdown]
# This function takes the customer's purchase history and calls the scoring endpoint:

# %%
client.deployments.ScoringMetaNames.show()
deployment_id = client.deployments.get_id(created_deployment)
# Out:
# ---------------------  ----  --------  ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# META_PROP NAME         TYPE  REQUIRED  SCHEMA
# NAME                   str   N
# INPUT_DATA             list  N         [{'name(optional)': 'string', 'id(optional)': 'string', 'fields(optional)': 'array[string]', 'values': 'array[array[string]]'}]
# INPUT_DATA_REFERENCES  list  N         [{'id(optional)': 'string', 'name(optional)': 'string', 'type(required)': 'string', 'connection(required)': {'href(required)': 'string'}, 'location(required)': {'bucket': 'string', 'path': 'string'}, 'schema(optional)': {'id(required)': 'string', 'fields(required)': [{'name(required)': 'string', 'type(required)': 'string', 'nullable(optional)': 'string'}]}}]
# OUTPUT_DATA_REFERENCE  dict  N         {'name(optional)': 'string', 'type(required)': 'string', 'connection(required)': {'href(required)': 'string'}, 'location(required)': {'bucket': 'string', 'path': 'string'}, 'schema(optional)': {'id(required)': 'string', 'fields(required)': [{'name(required)': 'string', 'type(required)': 'string', 'nullable(optional)': 'string'}]}}
# EVALUATIONS_SPEC       list  N         [{'id(optional)': 'string', 'input_target(optional)': 'string', 'metrics_names(optional)': 'array[string]'}]
# ENVIRONMENT_VARIABLES  dict  N
# ---------------------  ----  --------  ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
def get_cluster_from_watson_ml(fields, values):
    scoring_payload = {client.deployments.ScoringMetaNames.INPUT_DATA:[{'fields': fields, 'values': [values]}]}
    predictions = client.deployments.score(deployment_id, scoring_payload)
    return predictions['predictions'][0]['fields'][len(procedures_cols)+1]

# %% [markdown]
# Finally, call the functions defined above to get the product history, call the scoring endpoint, and get the cluster associated to customer 14887:

# %%
procedure_counts = get_procedure_counts_for_product(32)

fields = procedure_counts[0]
values = procedure_counts[1]
print("Cluster calculated by Watson ML = {}".format(get_cluster_from_watson_ml(fields, values)))
# Out:
# Cluster calculated by Watson ML = cluster

# %% [markdown]
# <a id="create_recomm"></a>
# ## 6. Create product recommendations
#
# Now you can create some procedure recommendations.
#
# First, run this cell to create a function that queries the database and finds the most popular items for a cluster. In this case, the **help_cluster** dataframe is the database.

# %%
def get_popular_procedures_in_cluster(cluster):            
    df_cluster_procedures = help_cluster.filter('cluster = {}'.format(cluster))            
    df_cluster_procedures_agg = df_cluster_procedures.groupby('cluster').sum()                
    row = df_cluster_procedures_agg.rdd.collect()[0]
    
    items = []
    for procedure_col in procedures_cols:
        field = 'sum({})'.format(procedure_col)        
        items.append((procedure_col, row[field]))
        sortedItems = sorted(items, key=lambda x: x[1], reverse=True) # Sort by score
        popular = [x for x in sortedItems if x[1] > 0]
        
    return popular

# %% [markdown]
# Now, run this cell to create a function that will calculate the recommendations based on a given cluster. This function finds the most popular procedure in the cluster, filters out procedure already purchased by the customer or currently in the customer's shopping cart, and finally produces a list of recommended procedure.

# %%
#from pyspark.sql.functions import desc
from pyspark.sql import SQLContext
sqlContext = SQLContext(sc)
def get_recommendations_by_cluster(cluster, purchased_quantities):
    # Existing customer products    
    user_procedures = []
    for i in range(0, len(procedures_cols)):
        if purchased_quantities[i] > 0:            
            user_procedures.append((procedures_cols[i], purchased_quantities[i]))
            #Aqui ele pega o total de procedimentos que o usuário acessou e coloca dentro da var user_procedures
               
    df_user_procedures = sc.parallelize(user_procedures).toDF(["PROCEDURES","COUNT"])    
    cluster_procedures = get_popular_procedures_in_cluster(cluster)        
    df_cluster_procedures = sc.parallelize(cluster_procedures).toDF(["PROCEDURES","COUNT"])
              
    print('Clustering...')
    df_recommended_procedures = df_cluster_procedures.alias('cl').join(df_user_procedures.alias('cu'), df_cluster_procedures['PROCEDURES'] == df_user_procedures['PROCEDURES'], 'leftouter')            
    return df_recommended_procedures
    
    # AQUI NÂO VAI SER APLICAR, porque temos que recomandar algo que ele já tenha acessado também e difícilmente ele não irá acessar nada
    # Caso o usuário não tenha acessado nada devemos retornar os mais acessaos GERAL
    #print('RECOMMENDED PROCEDURES2:')        
    #df_recommended_procedures_not_accessed_yet = df_recommended_procedures.filter('cu.PROCEDURES IS NULL').select('cl.PROCEDURES','cl.COUNT').sort(desc('cl.COUNT'))
    #df_recommended_procedures.show(10)

# %% [markdown]
# Next, run this cell to create a function that produces a list of recommended items based on the procedures and quantities in a user's cart. This function uses Watson Machine Learning to calculate the cluster based on the history cart contents and then calls the **get_recommendations_by_cluster** function.

# %%
# This function would be used to find recommendations based on the procedures and quantities in a user's cart
#ESSA FUNÇÃO NÃO TEM EFETIVIDADE PARA A HELP POR CONTA QUE AS RECOMENDAÇÕES SÃO COM BASE EM ACESSOS
def get_recommendations_for_history_cart(procedures, quantities):
    fields = []
    values = []
    for procedure_col in procedures_cols:
        field = '{}'.format(procedure_col)
        if procedure_col in procedures:
            value = quantities[procedures.index(procedure_col)]
        else:
            value = 0
        fields.append(field)
        values.append(value)
    return get_recommendations_by_cluster(get_cluster_from_watson_ml(fields, values), values)

# %% [markdown]
# Run this cell to create a function that produces a list of recommended items based on the purchase history of a customer. This function uses Watson Machine Learning to calculate the cluster based on the customer's purchase history and then calls the **get_recommendations_by_cluster** function.

# %%
# This function is used to find recommendations based on the purchase history of a customer
def get_recommendations_for_user_purchase_history(product_id):
    procedures_counts = get_procedure_counts_for_product(product_id)
    fields = procedures_counts[0]
    values = procedures_counts[1]
    return get_recommendations_by_cluster(get_cluster_from_watson_ml(fields, values), values)

# %% [markdown]
# Now you can take customer 12027 and produce a recommendation based on that customer's purchase history:

# %%
def get_procedures(recommendation):
    recommended_procedures = []        

    for index, row in enumerate(recommendation):                 
        recommended_procedures.append(row[0])
    
    return recommended_procedures

# %%
access_rows = access_base.take(10000000);

products_id=[32, 33]

#products_id=[45, 46, 47, 49, 51, 52, 53, 54, 55, 57, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 70, 71]
              


#for row in access_rows:
#    products_id.append(row['produto_id'])

# %%
import pandas as pd
products = []
procedures_by_product = pd.Series([])
product_df=[]
data = {'produto_id':  products_id}
product_df = pd.DataFrame (data, columns = ['produto_id'])

mergerd_recommended = []
for i in range(len(product_df)):
    for row in products_id:
        print(product_df['produto_id'][i], row)
        if(product_df['produto_id'][i] == row):
            procedures_recommended = get_recommendations_for_user_purchase_history(row)            
            mergerd_recommended.append(get_procedures(procedures_recommended.take(1000000)))            
            procedures_by_product[i] = mergerd_recommended
# Out:
# 32 32
# Clustering...
# 32 33
# 33 32
# 33 33
# Clustering...

# %%
product_df.insert(1, "RECOMMENDED_PROCEDURES_ARRAY", procedures_by_product)

# %%
display(product_df)
